# %% [markdown]
# # Ensemble Learning and Random Forests
#
# In ensemble learning the model does not consist of just one but many predictors that vote on the final prediction, which often leads to better predictions through capturing somehing similar to "wisdom of the crowd" in humans.
#
# Example: If you split the training set in 100 subsets and train classification decision trees separately on them, then combine them to a ensemble model where the final prediction depends on the majority vote, you have generated a **Random Forest classifier**.
#
# **Tips:**
# - Ensemble methods are best used towards the end of the model building phase when you already established a few good predictors to combine.
# - Make sure the individual predictors are as independent from another as possible to not capture the same mistake or type of error. This can be done by choosing predictors with very different algorithms
#
# Important concepts:
# - Bagging: training on random subsets (sampling) with replacement; short for bootstrap aggregation
# - Pasting: sampling without replacement
# - Boosting
# - Stacking

# %% [markdown]
# ## 1. Classification ensemble model example
#
# Consisting of Random Forest, Logistic Regression, and Support Vector Classifier
#
# Individual Performance (Validation Score):
# - Random Forest: 0.992
# - Logistic Regression: 0.87
# - Support Vector Machine Classifier: 0.9955
# - Hard Voting: 0.9935

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=10000, noise=0.14, random_state=32)

plt.plot(X[y==0, 0], X[y==0,1], "bs", alpha=0.4)
plt.plot(X[y==1, 0], X[y==1,1], "g^", alpha=0.4)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier

rnd_clf = RandomForestClassifier()
rnd_clf.fit(X_train, y_train)
rnd_clf.score(X_test, y_test) # test score
# Out:
# 0.992

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
log_reg.score(X_test, y_test) # test score
# Out:
# 0.87

# %%
from sklearn.svm import SVC

svm_clf = SVC()
svm_clf.fit(X_train, y_train)
svm_clf.score(X_test, y_test) # test score
# Out:
# 0.9955

# %%
# Hard Voting

from sklearn.ensemble import VotingClassifier

hard_voting_clf = VotingClassifier(
    estimators=[('rnd_clf', rnd_clf), ('log_reg', log_reg), ('svm_clf', svm_clf)],
    voting='hard'
    )

hard_voting_clf.fit(X_train, y_train)
hard_voting_clf.score(X_test, y_test) # test score
# Out:
# 0.9935

# %%
# Alternative: Loop through individual models

from sklearn.metrics import accuracy_score

for clf in (rnd_clf, log_reg, svm_clf, hard_voting_clf):
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(clf.__class__.__name__, accuracy_score(y_test, y_pred))
# Out:
# RandomForestClassifier 0.9925
# LogisticRegression 0.87
# SVC 0.9955
# VotingClassifier 0.994

# %% [markdown]
# If all predictors are able to predict class probability, i.e. they have the predict_proba() method, then we can use **soft voting where the class probability is the average of all predicted probabilities**. Thus, very confident models would have higher weights in the overall prediction which often leads to better results than hard voting.
#
# Note: We need to set the probability hyperparameter to True for SVC to work in soft voting

# %%
# Soft Voting
from sklearn.ensemble import VotingClassifier

soft_voting_clf = VotingClassifier(
    estimators=[('rnd_clf', rnd_clf), ('log_reg', log_reg), ('svm_clf', SVC(probability=True))],
    voting='soft'
    )

soft_voting_clf.fit(X_train, y_train)
soft_voting_clf.score(X_test, y_test) # test score
# Out:
# 0.9925

# %% [markdown]
# ## 2. Bagging and Pasting
#
# Instead of using very different training algorithms we can use the same algorithm on random subsets of the training set.
#
# When sampling is performed with replacement, this is called **bagging**, which stands for bootstrap aggregation.
#
# Sampling without replacement is called **pasting**.
#
# The predictions of the individual predictors are typically **aggregated using a statistical method** like in hard voting the most frequent predicted class or the average for regression.
#
# The individual predictors have higher bias than when trained on the entire training set, but aggregation reduces both bias and variance. Usually, the ensemble has a similar bias but lower variance than a single predictor trained on the training set.

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# Bagging: 
# 500 decision trees with each 1000 samples with replacement
bag_clf = BaggingClassifier(
    DecisionTreeClassifier(), n_estimators=500,
    max_samples=1000, bootstrap=True, n_jobs=-1
    )

bag_clf.fit(X_train, y_train)
bag_clf.score(X_test, y_test)
# Out:
# 0.992

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# Pasting: 
# 500 decision trees with each 1000 samples without replacement
past_clf = BaggingClassifier(
    DecisionTreeClassifier(), n_estimators=500,
    max_samples=1000, bootstrap=False, n_jobs=-1
    )

past_clf.fit(X_train, y_train)
past_clf.score(X_test, y_test)
# Out:
# 0.9905

# %% [markdown]
# A bagging ensemble can be evaluated without a separate validation set using **Out-of-Bag (OOB)** instances. OOB instances are data of the training set that are not used by the bagging predictor. The advantage of this is that you have more training instances since the validation set is unnecessary.

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Bagging: 
# with OOB evaluation
bag_clf = BaggingClassifier(
    DecisionTreeClassifier(), n_estimators=500,
    bootstrap=True, n_jobs=-1,
    oob_score=True
    )

bag_clf.fit(X_train, y_train)
print("OOB score: " + str(bag_clf.oob_score_))

# versus test set
y_pred = bag_clf.predict(X_test)
print("Validation score (Test Set): " + str(accuracy_score(y_test, y_pred)))
# Out:
# OOB score: 0.99075
# Validation score (Test Set): 0.9895

# %% [markdown]
# So far we only talked about sampling of instances. We can also do **feature sampling** in a similar way using BaggingClassifier and the hyperparameters bootstrap_features and max_features. This is particularily useful when dealing with a high-dimensional inputs.
#
#
# **Random Subspaces** method is used when we do feature sampling without instance sampling (bootstrap_features = True, max_samples=1.0)
#
# **Random Patches** method uses both feature sampling and instance sampling.

# %%
# Random Subspace: 
# doesnt make sense here with only two features
rndsub_clf = BaggingClassifier(
    DecisionTreeClassifier(), n_estimators=500,
    max_samples=1, bootstrap=False,
    max_features=0.6, bootstrap_features=True,
    n_jobs=-1
    )

rndsub_clf.fit(X_train, y_train)
rndsub_clf.score(X_test, y_test)
# Out:
# 0.51

# %%
# Random Patches: 
# doesnt make sense here with only two features
rndpat_clf = BaggingClassifier(
    DecisionTreeClassifier(), n_estimators=500,
    max_samples=0.6, bootstrap=True, 
    max_features=0.6, bootstrap_features=True,
    n_jobs=-1
    )

rndpat_clf.fit(X_train, y_train)
rndpat_clf.score(X_test, y_test)
# Out:
# 0.898

# %% [markdown]
# ## 3. Random Forest and Extra-Trees
#
# A **Random Forest** is an ensemble model consisting of decision trees and usually trained via the bagging method.
#
# Furthermore, random forest introduces extra randomness through searching for the best feature among a random subest of features when splitting a node. This trades higher bias for lower variance, resulting in an in general overall better model.
#
# **Extremely Randomized Trees** or Extra-Trees are usually trained on the whole data set without bagging, but introduce extra randomness by not splitting at the optimum for a feature but randomly.

# %% [markdown]
# ## 4. Boosting
#
# Boosting is an ensemble method that **combines several weak learners (predictors that do not do a good job in their own) into a strong learner**. This is usally done by training the weak learners sequentially to correct the error of the predecessor.
#
# The most well known boosting techniques are **AdaBoost** and **Gradient Boosting**.
#
# ### 4.1 AdaBoost
# We start by training a base classifier such as a Decision Tree and use it to make predictions on the training set. Then we increase the weights of the misclassified instances and run a second classifier using the updated weights, make again predictions and increase the weights for the misclassified instances, and so on. This is repeated until the number of predictors is reached or the model has zero training error.
#
# Very often AdaBoost is built using Decision trees of depth 1, also called decision stumps. When the classification error is calculated, we use weighted averages, so error of some instances are more important than others for the overall evaluation of the model.
#
# Because AdaBoost models give more weight to some of the harder cases, we need to check for outliers beforehand, otherwise the generalizability of the model can be reduced. Furthermore, the sequential nature of the training process doesn't allow for parallelized training.
#
# While AdaBoost is originally meant for binary classification problems, Scikit-Learn uses a multiclass version called SAMME. When class probabilities should be estimated, we can use a variant called SAMME.R. This also works for regression problems (AdaBoostRegressor).

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

ada_clf = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=1), # decision stumps
    n_estimators = 1000,
    algorithm="SAMME.R",
    learning_rate=0.5
)

ada_clf.fit(X_train, y_train)
print("Training score: " + str(ada_clf.score(X_train, y_train)))
print("Validation score: " + str(ada_clf.score(X_test, y_test)))
# Out:
# Training score: 0.997875
# Validation score: 0.9905

# %% [markdown]
# ### 4.2 Gradient Boosting
#
# Like AdaBoost, Gradient Boosting works by sequentially adding predictors to an ensemble to correct its predecessor. However, Gradient Boosting tries to fit the **new predictor to the residual errors** instead of tweaking all instance weights at every iteration.
#
# **Stochastic Gradient Boosting** uses only a subsample instead of the whole training data, which speeds up training considerably. The hyperparameter setting subsample=0.25 means that only 25% of the training instances are randomly selected for training a predictor. This reduces overfitting by trading in lower variance for higher bias.
#
# **XGBoost**, standing for Extreme Gradient Boosting, is the famous optimized implementation of gradient boosting.

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

X, y = make_regression(n_samples=200, n_features=2, shuffle=True, random_state=12)
plt.scatter(X[:,0], y, alpha=0.5)

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg1 = DecisionTreeRegressor(max_depth=2)
tree_reg1.fit(X, y)

y2 = y - tree_reg1.predict(X) # residual error round 1

print("Target for first instances: \n" + str(y[:5]))
print("Predictions for first instances: \n" + str(tree_reg1.predict(X)[:5]))
print("Residual error after round 1 for first instances: \n" + str(y2[:5]))
# Out:
# Target for first instances:
# [-69.83330294 -72.58745766  -7.15373396 -11.34477511 -98.56192178]
# Predictions for first instances:
# [-175.34423049  -57.47277143   10.11181435  -57.47277143  -57.47277143]
# Residual error after round 1 for first instances:
# [105.51092754 -15.11468623 -17.26554831  46.12799632 -41.08915035]

# %%
tree_reg2 = DecisionTreeRegressor(max_depth=2)
tree_reg2.fit(X, y2)

y3 = y - tree_reg2.predict(X) # residual error round 2

print("Target for first instances: \n" + str(y[:5]))
print("Predictions for first instances: \n" + str(tree_reg2.predict(X)[:5]))
print("Residual error after round 2 for first instances: \n" + str(y3[:5]))
# Out:
# Target for first instances:
# [-69.83330294 -72.58745766  -7.15373396 -11.34477511 -98.56192178]
# Predictions for first instances:
# [11.57909592 11.57909592 11.57909592 11.57909592 11.57909592]
# Residual error after round 2 for first instances:
# [ -81.41239886  -84.16655358  -18.73282988  -22.92387103 -110.1410177 ]

# %%
tree_reg3 = DecisionTreeRegressor(max_depth=2)
tree_reg3.fit(X, y3)

y4 = y - tree_reg3.predict(X) # residual error round 3

print("Target for first instances: \n" + str(y[:5]))
print("Predictions for first instances: \n" + str(tree_reg3.predict(X)[:5]))
print("Residual error after round 3 for first instances: \n" + str(y4[:5]))
# Out:
# Target for first instances:
# [-69.83330294 -72.58745766  -7.15373396 -11.34477511 -98.56192178]
# Predictions for first instances:
# [-159.19512912  -54.12129958   15.5997354   -54.12129958  -54.12129958]
# Residual error after round 3 for first instances:
# [ 89.36182618 -18.46615808 -22.75346936  42.77652447 -44.4406222 ]

# %%
# adding up the predictions of all trees
y_pred = sum(tree.predict(X) for tree in (tree_reg1, tree_reg2, tree_reg3))
print("Target for first instances: \n" + str(y[:5]))
print("Predictions for first instances after Gradient Boosting: \n" + str(y_pred[:5]))

# Model accuracy
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

rmse = np.sqrt(mean_squared_error(y,y_pred))
r2 = r2_score(y,y_pred)
print("RMSE: " + str(rmse))
print("R2 score: " + str(r2))
# Out:
# Target for first instances:
# [-69.83330294 -72.58745766  -7.15373396 -11.34477511 -98.56192178]
# Predictions for first instances after Gradient Boosting:
# [-322.96026369 -100.01497509   37.29064566 -100.01497509 -100.01497509]
# RMSE: 100.59159140375705
# R2 score: 0.13954572715632185

# %%
# Using Sklearn's GradientBoostingRegressor
from sklearn.ensemble import GradientBoostingRegressor

gbrt = GradientBoostingRegressor(max_depth=2, n_estimators=3, learning_rate=0.5)
gbrt.fit(X, y)

y_pred = gbrt.predict(X)

# Model accuracy
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

rmse = np.sqrt(mean_squared_error(y,y_pred))
r2 = r2_score(y,y_pred)
print("RMSE: " + str(rmse))
print("R2 score: " + str(r2))
# Out:
# RMSE: 42.36257986580874
# R2 score: 0.8473948328471699

# %% [markdown]
# The smaller learning_rate, the more trees are necessary to fit the training data, but the predictions will generalize better. This regularization technique is called **shrinkage**. Larger learning rates lead to higher bias while smaller learning rates lead to increased variance.
#
# **Early stopping** can help to find the optimum number of trees using the staged_predict() method.

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor

X_train, X_test, y_train, y_test = train_test_split(X, y)

gbrt = GradientBoostingRegressor(max_depth=2, n_estimators=500, random_state=0)
gbrt.fit(X_train, y_train)

errors = [mean_squared_error(y_test, y_pred) for y_pred in gbrt.staged_predict(X_test)]
best_n_estimator = np.argmin(errors)+1

# %%
# number of estimators for best model
best_n_estimator
# Out:
# 343

# %%
# resulting error
errors[best_n_estimator]
# Out:
# 155.46510523094432

# %%
# plot validation curve
plt.plot(np.arange(1,501,1), errors)
plt.ylabel("error")
plt.xlabel("n_estimators")
plt.title("Validation error")
# Out:
# Text(0.5, 1.0, 'Validation error')

# %%
# early stopping using warm_start
# stop training when validation error does not improve for five iterations

gbrt_2 = GradientBoostingRegressor(max_depth=2, warm_start=True, random_state=0)

min_val_error = float("inf")
error_going_up = 0

for n_estimators in range(1,1000):
    gbrt_2.n_estimators = n_estimators
    gbrt_2.fit(X_train, y_train)
    y_pred = gbrt_2.predict(X_test)
    val_error = mean_squared_error(y_test, y_pred)
    #print(val_error)
    if val_error < min_val_error:
        min_val_error = val_error
    else:
        error_going_up += 1
        if error_going_up == 5:
            break # early stopping

# %%
# best number of estimators
n_estimators
# Out:
# 97

# %%
# best validation error
val_error
# Out:
# 181.76673697187667

# %%
# Build model with optimal n_estimators

gbrt_best = GradientBoostingRegressor(max_depth=2, n_estimators=97, random_state=0)

gbrt_best.fit(X_train, y_train)

y_pred = gbrt_best.predict(X_test)

mean_squared_error(y_test, y_pred)
# Out:
# 181.76673697187667

# %% [markdown]
# ### 4.3 Histogram-based Boosting & LightGBM
#
# Histogram-based Boosting models are usually faster then the Gradient Boosting models described above. Instead of using the whole training data as input, the **input feature values are binned together like in a histogram** and thus the number of input values is reduced. Recommended for n_samples >= 10 000. The Scikit-learn implementation uses 255 bins by default.
#
# LightGBM implements a highly optimized histogram-based decision tree learning algorithm, which yields great advantages on both efficiency and memory consumption. Unlike most other boosting algorithms, **LightGBM can grow trees leaf-wise and not level-wise**, by choosing leafs with the max delta loss. This can improve performance but also lead to overfitting for smaller datasets. Using max_depth can control for that but then the trees grow level-wise.
#
# #### Comparison: Gradient Boosting vs Histogram-based vs. LightGBM

# %%
from sklearn.datasets import fetch_california_housing

cali_housing = fetch_california_housing()
X, y = cali_housing["data"], cali_housing["target"]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
X.shape
# Out:
# (20640, 8)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingRegressor

hist_gbrt = HistGradientBoostingRegressor(random_state=0, verbose=10)
# %time hist_gbrt.fit(X_train, y_train)
hist_gbrt.score(X_test, y_test)

# validation score 0.83455 in 4min 20s
# Out:
# Binning 0.001 GB of training data: 0.209 s
# Binning 0.000 GB of validation data: 0.123 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.58460, val loss: 0.58091, in 2.574s
# [2/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.51344, val loss: 0.51031, in 2.469s
# [3/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.45662, val loss: 0.45282, in 2.564s
# [4/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.40752, val loss: 0.40406, in 2.583s
# [5/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.36708, val loss: 0.36390, in 2.686s
# [6/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.33245, val loss: 0.32897, in 2.502s
# [7/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.30468, val loss: 0.30100, in 2.450s
# [8/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.27998, val loss: 0.27603, in 2.586s
# [9/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.25979, val loss: 0.25670, in 2.484s
# [10/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.24353, val loss: 0.24026, in 2.624s
# [11/100] 1 tree, 31 leaves, max depth = 7, train loss: 0.22767, val loss: 0.22445, in 2.747s
# [12/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.21461, val loss: 0.21186, in 2.669s
# [13/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.20397, val loss: 0.20159, in 2.554s
# [14/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.19383, val loss: 0.19182, in 2.954s
# [15/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.18518, val loss: 0.18317, in 2.884s
# [16/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.17799, val loss: 0.17649, in 2.730s
# [17/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.17135, val loss: 0.17031, in 3.078s
# [18/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.16532, val loss: 0.16539, in 3.253s
# [19/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.16040, val loss: 0.16076, in 2.640s
# [20/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.15521, val loss: 0.15590, in 2.618s
# [21/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.15025, val loss: 0.15142, in 2.730s
# [22/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.14539, val loss: 0.14731, in 2.665s
# [23/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.14171, val loss: 0.14422, in 2.582s
# [24/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.13735, val loss: 0.14090, in 2.479s
# [25/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.13407, val loss: 0.13821, in 1.534s
# [26/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.13089, val loss: 0.13546, in 2.634s
# [27/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.12807, val loss: 0.13277, in 2.572s
# [28/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.12551, val loss: 0.13070, in 2.684s
# [29/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.12307, val loss: 0.12867, in 2.997s
# [30/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.12111, val loss: 0.12709, in 3.014s
# [31/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.11915, val loss: 0.12550, in 3.168s
# [32/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.11788, val loss: 0.12474, in 3.254s
# [33/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.11642, val loss: 0.12378, in 2.759s
# [34/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.11502, val loss: 0.12275, in 2.793s
# [35/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.11355, val loss: 0.12173, in 2.839s
# [36/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.11216, val loss: 0.12078, in 3.092s
# [37/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.11099, val loss: 0.12014, in 2.674s
# [38/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.10983, val loss: 0.11941, in 2.867s
# [39/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.10874, val loss: 0.11876, in 3.247s
# [40/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.10742, val loss: 0.11774, in 2.933s
# [41/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.10659, val loss: 0.11723, in 2.418s
# [42/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.10554, val loss: 0.11682, in 2.972s
# [43/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.10460, val loss: 0.11625, in 2.896s
# [44/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.10351, val loss: 0.11565, in 2.938s
# [45/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.10267, val loss: 0.11529, in 2.494s
# [46/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.10180, val loss: 0.11490, in 2.723s
# [47/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.10109, val loss: 0.11480, in 2.516s
# [48/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.10043, val loss: 0.11462, in 2.541s
# [49/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.09937, val loss: 0.11377, in 3.010s
# [50/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.09880, val loss: 0.11366, in 2.901s
# [51/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.09786, val loss: 0.11285, in 3.246s
# [52/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.09723, val loss: 0.11273, in 3.053s
# [53/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.09656, val loss: 0.11242, in 3.258s
# [54/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.09590, val loss: 0.11206, in 2.304s
# [55/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.09523, val loss: 0.11160, in 2.676s
# [56/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.09463, val loss: 0.11145, in 2.601s
# [57/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.09399, val loss: 0.11110, in 2.876s
# [58/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.09340, val loss: 0.11125, in 2.960s
# [59/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.09271, val loss: 0.11071, in 2.473s
# [60/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.09201, val loss: 0.11050, in 2.385s
# [61/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.09142, val loss: 0.11039, in 2.468s
# [62/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.09088, val loss: 0.11036, in 2.508s
# [63/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.09016, val loss: 0.10999, in 2.494s
# [64/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.08965, val loss: 0.11005, in 2.380s
# [65/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.08919, val loss: 0.10976, in 2.467s
# [66/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.08873, val loss: 0.10975, in 2.263s
# [67/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.08821, val loss: 0.10944, in 2.491s
# [68/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.08781, val loss: 0.10930, in 2.111s
# [69/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.08729, val loss: 0.10888, in 2.331s
# [70/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.08680, val loss: 0.10861, in 2.355s
# [71/100] 1 tree, 31 leaves, max depth = 8, train loss: 0.08635, val loss: 0.10831, in 2.430s
# [72/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.08594, val loss: 0.10824, in 2.268s
# [73/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.08559, val loss: 0.10813, in 2.292s
# [74/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.08505, val loss: 0.10785, in 2.487s
# [75/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.08461, val loss: 0.10761, in 2.370s
# [76/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.08418, val loss: 0.10736, in 2.169s
# [77/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.08379, val loss: 0.10715, in 2.025s
# [78/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.08332, val loss: 0.10684, in 2.292s
# [79/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.08295, val loss: 0.10677, in 2.364s
# [80/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.08240, val loss: 0.10640, in 2.477s
# [81/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.08202, val loss: 0.10625, in 2.540s
# [82/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.08165, val loss: 0.10605, in 2.319s
# [83/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.08130, val loss: 0.10577, in 2.286s
# [84/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.08104, val loss: 0.10582, in 2.385s
# [85/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.08071, val loss: 0.10554, in 2.329s
# [86/100] 1 tree, 31 leaves, max depth = 14, train loss: 0.08025, val loss: 0.10530, in 2.120s
# [87/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.07986, val loss: 0.10514, in 2.359s
# [88/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.07952, val loss: 0.10517, in 2.346s
# [89/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.07919, val loss: 0.10504, in 2.404s
# [90/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.07887, val loss: 0.10522, in 2.274s
# [91/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.07850, val loss: 0.10497, in 2.456s
# [92/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.07818, val loss: 0.10498, in 2.362s
# [93/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.07781, val loss: 0.10491, in 2.532s
# [94/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.07748, val loss: 0.10490, in 2.359s
# [95/100] 1 tree, 31 leaves, max depth = 13, train loss: 0.07707, val loss: 0.10449, in 2.378s
# [96/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.07672, val loss: 0.10420, in 2.268s
# [97/100] 1 tree, 31 leaves, max depth = 12, train loss: 0.07651, val loss: 0.10429, in 2.969s
# [98/100] 1 tree, 31 leaves, max depth = 9, train loss: 0.07622, val loss: 0.10408, in 3.156s
# [99/100] 1 tree, 31 leaves, max depth = 10, train loss: 0.07598, val loss: 0.10393, in 2.447s
# [100/100] 1 tree, 31 leaves, max depth = 11, train loss: 0.07571, val loss: 0.10389, in 2.458s
# Fit 100 trees in 260.574 s, (3100 total leaves)
# Time spent computing histograms: 107.815s
# Time spent finding best splits:  64.030s
# Time spent applying splits:      77.643s
# Time spent predicting:           1.299s
# CPU times: user 52.8 s, sys: 8.73 s, total: 1min 1s
# Wall time: 4min 20s
# 0.8345512563382824

# %%
from lightgbm import LGBMRegressor

lgbmr = LGBMRegressor(verbose=10)
# %time lgbmr.fit(X_train, y_train)
lgbmr.score(X_test, y_test)

# validation score 0.8382 in 199ms
# Out:
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.000000
# [LightGBM] [Debug] init for col-wise cost 0.000042 seconds, init for row-wise cost 0.001197 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001620 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1838
# [LightGBM] [Info] Number of data points in the train set: 15480, number of used features: 8
# [LightGBM] [Info] Start training from score 2.069120
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# CPU times: user 2 s, sys: 111 ms, total: 2.11 s
# Wall time: 199 ms
# 0.8382085492795947

# %% [markdown]
# ## 5. Stacking
#
# Stacking is another ensemble method. The basic idea is that ensembles are **not aggregated by a simple function (like hard-voting) but through training another model**.
#
# In a regression problem for example, the individual models make a prediction each, which are then the inputs for the final predictor (called a **blender** or **meta learner**).
#
# It is necessary to split the training set into subsets (depending on the number of layers), for example:
# - subset 1 for training the first layer predictors
# - subset 2 making predictions upon in the first layer (these are the inputs for the second layer)
# - subset 3 (validation set) to see how well the overall stacked model works

# %%
# load MNIST

from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version=1)

X, y = mnist["data"], mnist["target"]

# %%
# train val test split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, shuffle=True, random_state=0)

print("Training set: " + str(round(len(X_train)/len(X),2)))
print("Validation set: " + str(round(len(X_val)/len(X),2)))
print("Test set: " + str(round(len(X_test)/len(X),2)))
# Out:
# Training set: 0.56
# Validation set: 0.24
# Test set: 0.2

# %% [markdown]
# #### Support Vector Machines

# %%
# train individual classifiers

from sklearn.svm import LinearSVC
lin_svc = LinearSVC()
# %time lin_svc.fit(X_train, y_train)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_val, lin_svc.predict(X_val)))
# Out:
# CPU times: user 1min 27s, sys: 244 ms, total: 1min 27s
# Wall time: 1min 27s
# 0.8855357142857143
# 0.8855357142857143
# /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
from sklearn.svm import SVC

rbf_svc = SVC(kernel="rbf", decision_function_shape="ovr")
# %time rbf_svc.fit(X_train, y_train)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_val, rbf_svc.predict(X_val)))
# Out:
# CPU times: user 3min 55s, sys: 446 ms, total: 3min 56s
# Wall time: 3min 56s
# 0.9779761904761904

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

softmax_reg = LogisticRegression(max_iter=500, multi_class="multinomial")
softmax_reg.fit(X_train, y_train)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_val, softmax_reg.predict(X_val)))
# Out:
# 0.9088095238095238
# /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
