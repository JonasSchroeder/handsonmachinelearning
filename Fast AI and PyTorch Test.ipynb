# %%
#id first_training
#caption Results from the first training
# CLICK ME
from fastai.vision.all import *
path = untar_data(URLs.PETS)/'images'

def is_cat(x): return x[0].isupper()
dls = ImageDataLoaders.from_name_func(
    path, get_image_files(path), valid_pct=0.2, seed=42,
    label_func=is_cat, item_tfms=Resize(224))

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(1)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/92 00:00<00:00]
#     </div>

# %%
pip install fastai
# Out:
# Collecting fastai
#   Downloading fastai-2.3.1-py3-none-any.whl (194 kB)
#      |████████████████████████████████| 194 kB 2.3 MB/s eta 0:00:01
# Requirement already satisfied: scikit-learn in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from fastai) (0.23.2)
# Requirement already satisfied: scipy in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from fastai) (1.5.4)
# Requirement already satisfied: pyyaml in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from fastai) (5.4.1)
# Collecting torchvision>=0.8.2
#   Downloading torchvision-0.9.1-cp38-cp38-macosx_10_9_x86_64.whl (13.2 MB)
#      |████████████████████████████████| 13.2 MB 12.0 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from fastai) (20.9)
# Requirement already satisfied: pip in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from fastai) (21.0.1)
# Requirement already satisfied: requests in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from fastai) (2.25.1)
# Collecting fastprogress>=0.2.4
#   Downloading fastprogress-1.0.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: pandas in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from fastai) (1.2.4)
# Requirement already satisfied: pillow>6.0.0 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from fastai) (8.2.0)
# Collecting fastcore<1.4,>=1.3.8
#   Downloading fastcore-1.3.20-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 4.0 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from fastai) (3.3.4)
# Collecting spacy<4
#   Downloading spacy-3.0.6-cp38-cp38-macosx_10_9_x86_64.whl (12.5 MB)
#      |████████████████████████████████| 12.5 MB 5.3 MB/s eta 0:00:01
# Collecting torch<1.9,>=1.7.0
#   Downloading torch-1.8.1-cp38-none-macosx_10_9_x86_64.whl (119.6 MB)
#      |████████████████████████████████| 119.6 MB 15.1 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from fastprogress>=0.2.4->fastai) (1.19.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (4.59.0)
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.1-cp38-cp38-macosx_10_9_x86_64.whl (450 kB)
#      |████████████████████████████████| 450 kB 6.4 MB/s eta 0:00:01
# Collecting spacy-legacy<3.1.0,>=3.0.4
#   Downloading spacy_legacy-3.0.5-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (3.0.5)
# Collecting typer<0.4.0,>=0.3.0
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Collecting pydantic<1.8.0,>=1.7.1
#   Downloading pydantic-1.7.4-cp38-cp38-macosx_10_9_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 40.8 MB/s eta 0:00:01
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (0.7.4)
# Collecting thinc<8.1.0,>=8.0.3
#   Downloading thinc-8.0.3-cp38-cp38-macosx_10_9_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 7.4 MB/s eta 0:00:01
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (2.0.5)
# Collecting catalogue<2.1.0,>=2.0.3
#   Downloading catalogue-2.0.4-py3-none-any.whl (16 kB)
# Requirement already satisfied: jinja2 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (2.11.3)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.5.2-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 4.8 MB/s  eta 0:00:01
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (0.8.2)
# Requirement already satisfied: setuptools in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (52.0.0.post20210125)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from packaging->fastai) (2.4.7)
# Collecting smart-open<4.0.0,>=2.2.0
#   Downloading smart_open-3.0.0.tar.gz (113 kB)
#      |████████████████████████████████| 113 kB 6.2 MB/s eta 0:00:01
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from requests->fastai) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from requests->fastai) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from requests->fastai) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from requests->fastai) (3.0.4)
# Requirement already satisfied: typing-extensions in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from torch<1.9,>=1.7.0->fastai) (3.7.4.3)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<4->fastai) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<4->fastai) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai) (0.10.0)
# Requirement already satisfied: six in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->fastai) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from pandas->fastai) (2021.1)
# Requirement already satisfied: joblib>=0.11 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->fastai) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/jonasschroeder/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->fastai) (2.1.0)
# Building wheels for collected packages: smart-open
#   Building wheel for smart-open (setup.py) ... done
#   Created wheel for smart-open: filename=smart_open-3.0.0-py3-none-any.whl size=107097 sha256=d6a0894762c19e4a7c31f31b0b6ff9e77bf2c7dac1dd48b7286ad00a389dfcce
#   Stored in directory: /Users/jonasschroeder/Library/Caches/pip/wheels/11/73/9a/f91ac1f1816436b16423617c5be5db048697ff152a9c4346f2
# Successfully built smart-open
# Installing collected packages: catalogue, typer, srsly, smart-open, pydantic, torch, thinc, spacy-legacy, pathy, torchvision, spacy, fastprogress, fastcore, fastai
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 5.1.0
#     Uninstalling smart-open-5.1.0:
#       Successfully uninstalled smart-open-5.1.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.8.2
#     Uninstalling pydantic-1.8.2:
#       Successfully uninstalled pydantic-1.8.2
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.5
#     Uninstalling thinc-7.4.5:
#       Successfully uninstalled thinc-7.4.5
# Successfully installed catalogue-2.0.4 fastai-2.3.1 fastcore-1.3.20 fastprogress-1.0.0 pathy-0.5.2 pydantic-1.7.4 smart-open-3.0.0 spacy-3.0.6 spacy-legacy-3.0.5 srsly-2.4.1 thinc-8.0.3 torch-1.8.1 torchvision-0.9.1 typer-0.3.2
# Note: you may need to restart the kernel to use updated packages.
